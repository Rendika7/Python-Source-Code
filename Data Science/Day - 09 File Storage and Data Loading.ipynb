# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("FileDataSet_PakOby/data_latihan.csv", sep = ";")
# directory file ini bisa di assignment ke dalam variabel lalu dipakai variabelnya
# Sep itu untuk pemisah didalam file csv nya, jadi harus diperiksa dulu pemisah nya itu apa...
df
# Out:
#     #node1    node2       node1_string_id       node2_string_id  \
# 0     ACE2    MEP1A  9606.ENSP00000389326  9606.ENSP00000230588
# 1     ACE2      REN  9606.ENSP00000389326  9606.ENSP00000272190
# 2     ACE2  SLC6A19  9606.ENSP00000389326  9606.ENSP00000305302
# 3     ACE2   CLEC4M  9606.ENSP00000389326  9606.ENSP00000316228
# 4     ACE2     DPP4  9606.ENSP00000389326  9606.ENSP00000353731
# 5     ACE2      AGT  9606.ENSP00000389326  9606.ENSP00000355627
# 6     ACE2     PRCP  9606.ENSP00000389326  9606.ENSP00000377055
# 7     ACE2  TMPRSS2  9606.ENSP00000389326  9606.ENSP00000381588
# 8     ACE2   SLC1A7  9606.ENSP00000389326  9606.ENSP00000478639
# 9     ACE2      MME  9606.ENSP00000389326  9606.ENSP00000418525
# 10     AGT      REN  9606.ENSP00000355627  9606.ENSP00000272190
# 11     AGT     PRCP  9606.ENSP00000355627  9606.ENSP00000377055
# 12     AGT      MME  9606.ENSP00000355627  9606.ENSP00000418525
# 13    DPP4    MEP1A  9606.ENSP00000353731  9606.ENSP00000230588
# ...

# %%
df.shape
# Baris , Kolom
# Out:
# (25, 13)

# %%
df.to_csv("FileDataSet_PakOby/Data_Latihan_Convert_to_CSV_Comma")

# %%
df2 = pd.read_json("FileDataSet_PakOby/data_latihan.json", orient = "split")
df2

#caranya sama aja kayak yang diatas tapi tambahin orient = "split". (Cari di web pandas langsung "Pandas Read Json")
# Out:
#          Hasil 1  Hasil 2  Hasil 3  Hasil 4  Hasil 5
# data 1        29       32       17       18       44
# data 2        91       54       62       46       38
# data 3        45        6       10       41       16
# data 4        54       31       61       22       20
# data 5        28       68       33       94       81
# data 6        63       86       83       18       22
# data 7        23       23       49       47       85
# data 8        85       30       19       51       63
# data 9        68       72       31       10       55
# data 10       46       77       35       61       95
# data 11        7       39       88       98       10
# data 12        1       58       62       99        6
# data 13       51       55       92       23       16
# data 14       90        6       36       70       50
# data 15       37       86       78       90       66
# data 16       77       85       31       49       77
# data 17       97       99       63       28        3
# ...

# %%
xml = '''<?xml version='1.0' encoding='utf-8'?>
<data xmlns="http://example.com">
 <row>
   <shape>square</shape>
   <degrees>360</degrees>
   <sides>4.0</sides>
 </row>
 <row>
   <shape>circle</shape>
   <degrees>360</degrees>
   <sides/>
 </row>
 <row>
   <shape>triangle</shape>
   <degrees>180</degrees>
   <sides>3.0</sides>
 </row>
</data>'''

df3 = pd.read_xml(xml)
df3.to_xml("FileDataSet_PakOby/Data_Latihan_Convert_to_xml")
df3
# Out:
#       shape  degrees  sides
# 0    square      360    4.0
# 1    circle      360    NaN
# 2  triangle      180    3.0

# %%
df3 = pd.read_xml("FileDataSet_PakOby/data_latihan.xml")
df3
# Out:
#    experimentList  interactorList  interactionList
# 0             NaN             NaN              NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 df4 = pd.read_tsv("FileDataSet_PakOby/data_latihan.tsv")
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_tsv'

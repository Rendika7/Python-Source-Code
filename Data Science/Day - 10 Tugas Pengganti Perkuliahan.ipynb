# %%
#Import library yang akan digunakan untuk menunjang pengerjaan
import numpy as np
import pandas as pd

# %%
#Memanggil file csv yang telah diberikan
Filepath = "FileDataSet_PakOby/10. Transshipment-vessels.csv"
df1 = pd.read_csv(Filepath, sep = ",")
pd.set_option("display.max_row", None)
df1
# Out:
#              mmsi                  shipname callsign flag        imo  \
# 0     306117000.0              SIERRALAUREL     PJBQ  ANT  9163403.0
# 1     306873000.0               SIERRALEYRE     PJJZ  ANT  9135822.0
# 2        309681.0               GREENBRAZIL    C6WH6  BHS  9045792.0
# 3     308735000.0             NOVA BRETAGNE    C6JI7  BHS  9000364.0
# 4     311000682.0               SIERRA LARA    C6DI3  BHS  9120205.0
# 5     311000433.0              SILVER PEARL    C6CC5  BHS  8400050.0
# 6     311000709.0              SIERRA LEYRE    C6DL3  BHS  9135822.0
# 7     311043900.0            GREENCONCORDIA    C6YS7  BHS  9011038.0
# 8     308572000.0               RUNAWAY BAY    C6PX2  BHS  9019640.0
# 9     308228000.0               GREEN OCEAN    C6VY8  BHS  9001916.0
# 10    308541000.0               GREEN SELJE    C6IB5  BHS  8804529.0
# 11    308743000.0                 TAMA STAR    C6MA6  BHS  8517358.0
# 12    308868000.0           GREEN GUATEMALA    C6WA6  BHS  8912144.0
# ...

# %%
# Nilai yang first stampnya 2017 keatas
Tahun_2017 = df1[(df1['first_timestamp'] < "2018-01-01") & (df1['first_timestamp'] >= "2017-01-01")]
Tahun_2017.count()
# Out:
# mmsi               44
# shipname           44
# callsign           44
# flag               44
# imo                44
# first_timestamp    44
# last_timestamp     44
# dtype: int64

# %%
# Nilai yang first stampnya 2018 keatas
Tahun_2018 = df1[df1.first_timestamp >= "2018-01-01"]
Tahun_2018
# Out:
#              mmsi          shipname callsign flag        imo  \
# 0     306117000.0      SIERRALAUREL     PJBQ  ANT  9163403.0
# 2        309681.0       GREENBRAZIL    C6WH6  BHS  9045792.0
# 314   636015529.0             IERAX    D5BH5  LBR        NaN
# 316     3530564.0        BAYPHOENIX    A8OE5  LBR  9047271.0
# 319   636018500.0       BAY PHOENIX    A8OE5  LBR  9047271.0
# 365   636018501.0     WATER PHOENIX    A8OE3  LBR  9045168.0
# 369   636018499.0    LAGOON PHOENIX    A8OE4  LBR  9047245.0
# 532   354463048.0          XING YUN    3FVB3  PAN  8203816.0
# 796   273385132.0            URGULL    UBZN7  RUS  8810190.0
# 800   273385143.0            URGULL    UBZN7  RUS  8810190.0
# 848   273449788.0          PLUTONAS     UERU  RUS  7808322.0
# 949   415518424.0  LIANCHUANSHENG66     BEGE  TWN  7305722.0
# 994   367632260.0         NOTORIOUS  WDH5866  USA  7202061.0
# 1011  367348340.0         HARMONY I  WDE4075  USA  7917666.0
#
# ...

# %%
# Nilai yang first stampnya 2018 keatas
Tahun_2018 = df1[df1.first_timestamp <= "2018-01-01"]
Tahun_2018
# Out:
#              mmsi                  shipname callsign flag        imo  \
# 1     306873000.0               SIERRALEYRE     PJJZ  ANT  9135822.0
# 3     308735000.0             NOVA BRETAGNE    C6JI7  BHS  9000364.0
# 4     311000682.0               SIERRA LARA    C6DI3  BHS  9120205.0
# 5     311000433.0              SILVER PEARL    C6CC5  BHS  8400050.0
# 6     311000709.0              SIERRA LEYRE    C6DL3  BHS  9135822.0
# 7     311043900.0            GREENCONCORDIA    C6YS7  BHS  9011038.0
# 8     308572000.0               RUNAWAY BAY    C6PX2  BHS  9019640.0
# 9     308228000.0               GREEN OCEAN    C6VY8  BHS  9001916.0
# 10    308541000.0               GREEN SELJE    C6IB5  BHS  8804529.0
# 11    308743000.0                 TAMA STAR    C6MA6  BHS  8517358.0
# 12    308868000.0           GREEN GUATEMALA    C6WA6  BHS  8912144.0
# 13    309165000.0             GREEN KLIPPER    C6VY9  BHS  9001904.0
# 14    309281000.0              GREEN ITALIA    C6WH9  BHS  9045780.0
# ...

# %%
# Nilai yang first stampnya 2017 keatas
Tahun_2017 = df1[(df1['first_timestamp'] < "2018-01-01") & (df1['first_timestamp'] >= "2017-01-01")]
Tahun_2017.count()
# Out:
# mmsi               44
# shipname           44
# callsign           44
# flag               44
# imo                44
# first_timestamp    44
# last_timestamp     44
# dtype: int64

# %% [markdown]
# # Fixing Nilai First_TimeStamp

# %%
#Mengubah value dari tabel "first_timestamp" yang dimana pertamanya bertipe srting menjadi kedalam date and time menggunakan slicing multiple

import re

Keterangan_Waktu = list(df1["first_timestamp"])
List_Waktu = []
for i in range (1070) :
    Waktu = Keterangan_Waktu[i]
    Slicing = re.split("T|Z",Waktu)
    List_Waktu.append(Slicing)
List_Waktu
# Out:
# [['2018-03-29', '08:34:21', ''],
#  ['2012-01-01', '01:06:00', ''],
#  ['2018-06-29', '10:34:00', ''],
#  ['2012-01-01', '00:39:08', ''],
#  ['2017-07-03', '10:28:05', ''],
#  ['2015-08-19', '10:00:02', ''],
#  ['2017-10-12', '08:51:41', ''],
#  ['2012-01-03', '22:17:16', ''],
#  ['2012-01-01', '00:28:40', ''],
#  ['2012-01-03', '11:20:45', ''],
#  ['2012-01-06', '15:54:49', ''],
#  ['2012-01-03', '22:03:55', ''],
#  ['2012-01-03', '11:04:19', ''],
#  ['2012-01-01', '02:25:08', ''],
#  ['2012-01-01', '00:52:25', ''],
#  ['2012-01-01', '00:04:56', ''],
#  ['2012-01-01', '00:20:15', ''],
#  ['2013-03-26', '11:30:49', ''],
#  ['2012-01-21', '11:08:26', ''],
#  ['2012-01-01', '06:38:54', ''],
#  ['2012-01-05', '01:34:11', ''],
#  ['2012-01-01', '00:05:36', ''],
#  ['2012-01-03', '22:46:52', ''],
#  ['2012-01-03', '16:43:04', ''],
#  ['2012-01-03', '01:52:53', ''],
#  ['2012-01-03', '17:33:57', ''],
#  ['2012-01-01', '08:00:08', ''],
#  ['2014-05-04', '21:25:02', ''],
# ...

# %%
none = [[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None]]
Kosong = pd.DataFrame(none)
Kosong.index = np.arange(1070,1124)
Kosong.columns = ["first_timestamp_date","first_timestamp_time"]

# %%
#convert list kedalam dataframe, dan mengubah nama kolom, serta menghapus kolom yang tidak digunakan.

Tabel_Waktu_first = pd.DataFrame(List_Waktu)
Tabel_Waktu_first.columns = ["first_timestamp_date","first_timestamp_time","None"]
del Tabel_Waktu_first['None']
Tabel_Waktu_first = pd.concat([Tabel_Waktu_first,Kosong])
Tabel_Waktu_first
# Out:
#      first_timestamp_date first_timestamp_time
# 0              2018-03-29             08:34:21
# 1              2012-01-01             01:06:00
# 2              2018-06-29             10:34:00
# 3              2012-01-01             00:39:08
# 4              2017-07-03             10:28:05
# 5              2015-08-19             10:00:02
# 6              2017-10-12             08:51:41
# 7              2012-01-03             22:17:16
# 8              2012-01-01             00:28:40
# 9              2012-01-03             11:20:45
# 10             2012-01-06             15:54:49
# 11             2012-01-03             22:03:55
# 12             2012-01-03             11:04:19
# 13             2012-01-01             02:25:08
# 14             2012-01-01             00:52:25
# 15             2012-01-01             00:04:56
# 16             2012-01-01             00:20:15
# 17             2013-03-26             11:30:49
# 18             2012-01-21             11:08:26
# ...

# %%
df2 = pd.concat([df1,Tabel_Waktu_first], axis = 1)
del df2["first_timestamp"]
df2
# Out:
#              mmsi                  shipname callsign flag        imo  \
# 0     306117000.0              SIERRALAUREL     PJBQ  ANT  9163403.0
# 1     306873000.0               SIERRALEYRE     PJJZ  ANT  9135822.0
# 2        309681.0               GREENBRAZIL    C6WH6  BHS  9045792.0
# 3     308735000.0             NOVA BRETAGNE    C6JI7  BHS  9000364.0
# 4     311000682.0               SIERRA LARA    C6DI3  BHS  9120205.0
# 5     311000433.0              SILVER PEARL    C6CC5  BHS  8400050.0
# 6     311000709.0              SIERRA LEYRE    C6DL3  BHS  9135822.0
# 7     311043900.0            GREENCONCORDIA    C6YS7  BHS  9011038.0
# 8     308572000.0               RUNAWAY BAY    C6PX2  BHS  9019640.0
# 9     308228000.0               GREEN OCEAN    C6VY8  BHS  9001916.0
# 10    308541000.0               GREEN SELJE    C6IB5  BHS  8804529.0
# 11    308743000.0                 TAMA STAR    C6MA6  BHS  8517358.0
# 12    308868000.0           GREEN GUATEMALA    C6WA6  BHS  8912144.0
# ...

# %% [markdown]
# # Fixing Nilai Last_TimeStamp

# %%
#Mengubah value dari tabel "Last_timestamp" yang dimana pertamanya bertipe srting menjadi kedalam date and time menggunakan slicing multiple

import re

Keterangan_Waktu = list(df1["last_timestamp"])
List_Waktu_last = []
for i in range (1070) :
    Waktu = Keterangan_Waktu[i]
    Slicing = re.split("T|Z",Waktu)
    List_Waktu_last.append(Slicing)
List_Waktu_last
# Out:
# [['2018-06-30', '17:08:41', ''],
#  ['2012-06-26', '08:58:28', ''],
#  ['2018-06-30', '23:47:40', ''],
#  ['2013-09-12', '10:03:48', ''],
#  ['2018-06-30', '23:35:36', ''],
#  ['2018-06-30', '23:57:13', ''],
#  ['2018-06-30', '06:08:40', ''],
#  ['2013-09-09', '11:44:22', ''],
#  ['2017-02-08', '06:13:05', ''],
#  ['2018-06-30', '23:57:00', ''],
#  ['2018-06-30', '23:48:42', ''],
#  ['2015-05-21', '03:08:05', ''],
#  ['2018-06-30', '00:42:24', ''],
#  ['2018-06-30', '23:46:54', ''],
#  ['2018-06-30', '23:44:01', ''],
#  ['2018-06-30', '23:01:06', ''],
#  ['2013-03-13', '03:33:23', ''],
#  ['2013-03-30', '10:46:25', ''],
#  ['2013-03-14', '02:30:34', ''],
#  ['2014-07-18', '01:00:00', ''],
#  ['2018-06-30', '22:40:08', ''],
#  ['2018-06-30', '18:53:35', ''],
#  ['2018-06-30', '15:50:35', ''],
#  ['2018-06-30', '20:15:13', ''],
#  ['2018-06-30', '22:51:02', ''],
#  ['2018-06-30', '23:58:02', ''],
#  ['2017-05-09', '09:21:27', ''],
#  ['2014-05-05', '08:38:30', ''],
# ...

# %%
none = [[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None],[None,None]]
Kosong = pd.DataFrame(none)
Kosong.index = np.arange(1070,1124)
Kosong.columns = ["last_timestamp_date","last_timestamp_time"]

# %%
#convert list kedalam dataframe, dan mengubah nama kolom, serta menghapus kolom yang tidak digunakan.

Tabel_Waktu_last = pd.DataFrame(List_Waktu_last)
Tabel_Waktu_last.columns = ["last_timestamp_date","last_timestamp_time","None"]
del Tabel_Waktu_last['None']
Tabel_Waktu_last = pd.concat([Tabel_Waktu_last,Kosong])
Tabel_Waktu_last
# Out:
#      last_timestamp_date last_timestamp_time
# 0             2018-06-30            17:08:41
# 1             2012-06-26            08:58:28
# 2             2018-06-30            23:47:40
# 3             2013-09-12            10:03:48
# 4             2018-06-30            23:35:36
# 5             2018-06-30            23:57:13
# 6             2018-06-30            06:08:40
# 7             2013-09-09            11:44:22
# 8             2017-02-08            06:13:05
# 9             2018-06-30            23:57:00
# 10            2018-06-30            23:48:42
# 11            2015-05-21            03:08:05
# 12            2018-06-30            00:42:24
# 13            2018-06-30            23:46:54
# 14            2018-06-30            23:44:01
# 15            2018-06-30            23:01:06
# 16            2013-03-13            03:33:23
# 17            2013-03-30            10:46:25
# 18            2013-03-14            02:30:34
# 19            2014-07-18            01:00:00
# ...

# %%
df2 = pd.concat([df2,Tabel_Waktu_last], axis = 1)
del df2["last_timestamp"]
df2
# Out:
#              mmsi                  shipname callsign flag        imo  \
# 0     306117000.0              SIERRALAUREL     PJBQ  ANT  9163403.0
# 1     306873000.0               SIERRALEYRE     PJJZ  ANT  9135822.0
# 2        309681.0               GREENBRAZIL    C6WH6  BHS  9045792.0
# 3     308735000.0             NOVA BRETAGNE    C6JI7  BHS  9000364.0
# 4     311000682.0               SIERRA LARA    C6DI3  BHS  9120205.0
# 5     311000433.0              SILVER PEARL    C6CC5  BHS  8400050.0
# 6     311000709.0              SIERRA LEYRE    C6DL3  BHS  9135822.0
# 7     311043900.0            GREENCONCORDIA    C6YS7  BHS  9011038.0
# 8     308572000.0               RUNAWAY BAY    C6PX2  BHS  9019640.0
# 9     308228000.0               GREEN OCEAN    C6VY8  BHS  9001916.0
# 10    308541000.0               GREEN SELJE    C6IB5  BHS  8804529.0
# 11    308743000.0                 TAMA STAR    C6MA6  BHS  8517358.0
# 12    308868000.0           GREEN GUATEMALA    C6WA6  BHS  8912144.0
# ...

# %% [markdown]
# # Olah Data

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1124 entries, 0 to 1123
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   mmsi                  1070 non-null   float64
#  1   shipname              1123 non-null   object
#  2   callsign              1106 non-null   object
#  3   flag                  1124 non-null   object
#  4   imo                   1074 non-null   float64
#  5   first_timestamp_date  1070 non-null   object
#  6   first_timestamp_time  1070 non-null   object
#  7   last_timestamp_date   1070 non-null   object
#  8   last_timestamp_time   1070 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 79.2+ KB

# %%
#Untuk mengetahui di setiap kolom ada berapa missing value(Nilai kosong yang tidak terisi)
df2.isnull().sum()
# Out:
# mmsi                    54
# shipname                 1
# callsign                18
# flag                     0
# imo                     50
# first_timestamp_date    54
# first_timestamp_time    54
# last_timestamp_date     54
# last_timestamp_time     54
# dtype: int64

# %%
#Mengetahui nama kolom yang ada di file CSV
column_names = []
for col in df2.columns :
    column_names.append(col)
print(column_names)
# Out:
# ['mmsi', 'shipname', 'callsign', 'flag', 'imo', 'first_timestamp_date', 'first_timestamp_time', 'last_timestamp_date', 'last_timestamp_time']

# %%
#Mengetahui ukuran dari tabel yang ada di file csv tersebut
df2.shape
# Out:
# (1124, 9)

# %%
#Mengetahui semua isi dari kolom mmsi dan mengidentifikasi yang tidak mempunya mmsi sebagai ilegal
#Mmsi yang NaN = Ilegal Ship

Cek = df2["mmsi"].isna()
Cek_MMSI = Cek.tolist()

count = 0
for i in Cek_MMSI :
    if i == True :
        count+=1
print(count)
# Out:
# 54

# %%
#Mengetahui semua isi dari kolom flag dan diurutkan agar lebih nyaman di olah
countries = np.array(df2["flag"])
countries = countries.tolist()
countries.sort()
print(countries)
# Out:
# ['ANT', 'ANT', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BHS', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BLZ', 'BMU', 'BRB', 'BRB', 'CAN', 'CAN', 'CAN', 'CHL', 'CHL', 'CHL', 'CHL', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'CHN', 'COK', 'COK', 'COK', 'COL', 'COM', 'COM', 'COM', 'CO
# ...

# %%
#Mengambil isi yang unique dari kolom flag yang telah dipecah tadi. unique berrti nilai yang berbeda dari satu dengan nilai yang lainnya
countries = np.array(df2["flag"])
countries = countries.tolist()
unique_country = pd.unique(countries)
unique_country = unique_country.tolist()
tipe = type(unique_country)
print(tipe)
print(unique_country)
# Out:
# <class 'list'>
# ['ANT', 'BHS', 'BLZ', 'BMU', 'BRB', 'CAN', 'CHL', 'CHN', 'COK', 'COL', 'COM', 'CUW', 'CYM', 'CYP', 'DMA', 'ESP', 'FJI', 'FRO', 'FSM', 'GHA', 'HND', 'IDN', 'IRN', 'JPN', 'KHM', 'KIR', 'KNA', 'KOR', 'LBR', 'LTU', 'MDA', 'MDV', 'MHL', 'MLT', 'MNG', 'MUS', 'MYS', 'NIU', 'NLD', 'NOR', 'PAN', 'PHL', 'PLW', 'RUS', 'SAU', 'SEN', 'SGP', 'SLE', 'SYC', 'TGO', 'THA', 'TWN', 'TZA', 'UKR', 'UNK', 'USA', 'VCT', 'VUT']

# %%
for i in unique_country :
    Negara = i
    Info = df1[(df2.flag == Negara)]
    print(Info)
    print("-"*50)
# Out:
#           mmsi      shipname callsign flag        imo       first_timestamp  \
# 0  306117000.0  SIERRALAUREL     PJBQ  ANT  9163403.0  2018-03-29T08:34:21Z
# 1  306873000.0   SIERRALEYRE     PJJZ  ANT  9135822.0  2012-01-01T01:06:00Z
#
#          last_timestamp
# 0  2018-06-30T17:08:41Z
# 1  2012-06-26T08:58:28Z
# --------------------------------------------------
#              mmsi          shipname callsign flag        imo  \
# 2        309681.0       GREENBRAZIL    C6WH6  BHS  9045792.0
# 3     308735000.0     NOVA BRETAGNE    C6JI7  BHS  9000364.0
# 4     311000682.0       SIERRA LARA    C6DI3  BHS  9120205.0
# 5     311000433.0      SILVER PEARL    C6CC5  BHS  8400050.0
# 6     311000709.0      SIERRA LEYRE    C6DL3  BHS  9135822.0
# 7     311043900.0    GREENCONCORDIA    C6YS7  BHS  9011038.0
# 8     308572000.0       RUNAWAY BAY    C6PX2  BHS  9019640.0
# 9     308228000.0       GREEN OCEAN    C6VY8  BHS  9001916.0
# ...

# %%
#Mengetahui berapa kali suatu Negara itu muncul dalam kolom flag

Jumlah = np.unique(countries,return_counts=True)
Jumlah_Negara = np.asarray(Jumlah).T
Jumlah_Negara = Jumlah_Negara.tolist()
Tabel_Jumlah_Negara = pd.DataFrame(Jumlah_Negara)
Tabel_Jumlah_Negara.columns = ["Negara","Jumlah"]
Tabel_Jumlah_Negara = Tabel_Jumlah_Negara.sort_values(by=["Jumlah"])

Negara_Terpilih = Tabel_Jumlah_Negara.iloc [20:33,0:]
Negara_Terpilih
# Out:
#    Negara Jumlah
# 23    JPN     15
# 47    SLE     16
# 34    MNG      2
# 0     ANT      2
# 4     BRB      2
# 31    MDV      2
# 24    KHM     20
# 2     BLZ     21
# 40    PAN    219
# 26    KNA     23
# 39    NOR     23
# 43    RUS    237
# 5     CAN      3

# %%
#mengambil seluruh data perbarisnya dengan patokan nilai dari flag yang dicari
Indonesia = df2[df2["flag"] == "IDN"]
Indonesia
# Out:
#             mmsi           shipname callsign flag        imo  \
# 169  525010170.0  SUMBERSUKSESUTAMA     PNOP  IDN  7905027.0
#
#     first_timestamp_date first_timestamp_time last_timestamp_date  \
# 169           2012-09-05             02:08:26          2016-05-09
#
#     last_timestamp_time
# 169            06:49:45

# %%
#Mengurutkan secara Ascending berdasarkan date dari kolom "first_timestamp_date"
Terawal = df2.sort_values(by=["first_timestamp_date"])
Terawal.head()
# Out:
#              mmsi         shipname callsign flag        imo  \
# 1004  367124290.0     CAPE DENBIGH  WDC3659  USA  8332136.0
# 152   224124000.0     SALICA FRIGO     EBTL  ESP  9238703.0
# 481   371210000.0        RAINFROST    3EGY7  PAN  8521804.0
# 158   627047000.0      VOLTA GLORY     9GII  GHA  8323604.0
# 429   258799000.0  RONJA HARVESTER     LAWU  NOR  9392547.0
#
#      first_timestamp_date first_timestamp_time last_timestamp_date  \
# 1004           2012-01-01             00:04:40          2018-03-19
# 152            2012-01-01             08:59:38          2018-06-29
# 481            2012-01-01             00:02:18          2013-07-05
# 158            2012-01-01             11:32:46          2018-06-30
# 429            2012-01-01             00:04:35          2018-06-30
#
#      last_timestamp_time
# 1004            22:02:00
# 152             15:02:33
# 481             14:03:56
# 158             23:05:58
# 429             23:58:37

# %%
#Mengurutkan secara Descending berdasarkan date dari kolom "first_timestamp_date"
Terakhir = df2.sort_values(by=["first_timestamp_date"],ascending = False)
Terakhir.head()
# Out:
#             mmsi          shipname callsign flag        imo  \
# 2       309681.0       GREENBRAZIL    C6WH6  BHS  9045792.0
# 316    3530564.0        BAYPHOENIX    A8OE5  LBR  9047271.0
# 800  273385143.0            URGULL    UBZN7  RUS  8810190.0
# 796  273385132.0            URGULL    UBZN7  RUS  8810190.0
# 949  415518424.0  LIANCHUANSHENG66     BEGE  TWN  7305722.0
#
#     first_timestamp_date first_timestamp_time last_timestamp_date  \
# 2             2018-06-29             10:34:00          2018-06-30
# 316           2018-06-25             02:30:55          2018-06-30
# 800           2018-06-22             00:09:42          2018-06-24
# 796           2018-06-21             12:05:32          2018-06-21
# 949           2018-05-28             00:14:33          2018-06-30
#
#     last_timestamp_time
# 2              23:47:40
# 316            12:57:31
# 800            18:13:55
# 796            15:35:33
# 949            18:31:47

# %% [markdown]
# # Percobaan

# %%
import re

txt = "2018-06-30T17:08:41Z"

Slicing = re.split("T|Z",txt)

print(Slicing[0])
# Out:
# 2018-06-30

# %%
# Mengetahui semua isi dari kolom mmsi dan mengidentifikasi yang tidak mempunya mmsi sebagai ilegal


Nomor_Induk_Kapal = np.array(df1["mmsi"])
Nomor_Induk_Kapal = Nomor_Induk_Kapal.tolist()


banyak = 0
for i in range (len(Nomor_Induk_Kapal)-1) :
    if Nomor_Induk_Kapal[i] == True :
        banyak +=1
print(banyak)
# Out:
# 0

# %%
def Pemisah (Data,x) :
    List_Waktu = []
    for i in range (x) :
        Waktu = Data[i]
        Slicing = re.split("T|Z",Waktu)
        List_Waktu.append(Slicing)
    print(List_Waktu)
Pemisah(Keterangan_Waktu,1070)
# Out:
# [['2018-06-30', '17:08:41', ''], ['2012-06-26', '08:58:28', ''], ['2018-06-30', '23:47:40', ''], ['2013-09-12', '10:03:48', ''], ['2018-06-30', '23:35:36', ''], ['2018-06-30', '23:57:13', ''], ['2018-06-30', '06:08:40', ''], ['2013-09-09', '11:44:22', ''], ['2017-02-08', '06:13:05', ''], ['2018-06-30', '23:57:00', ''], ['2018-06-30', '23:48:42', ''], ['2015-05-21', '03:08:05', ''], ['2018-06-30', '00:42:24', ''], ['2018-06-30', '23:46:54', ''], ['2018-06-30', '23:44:01', ''], ['2018-06-30', '23:01:06', ''], ['2013-03-13', '03:33:23', ''], ['2013-03-30', '10:46:25', ''], ['2013-03-14', '02:30:34', ''], ['2014-07-18', '01:00:00', ''], ['2018-06-30', '22:40:08', ''], ['2018-06-30', '18:53:35', ''], ['2018-06-30', '15:50:35', ''], ['2018-06-30', '20:15:13', ''], ['2018-06-30', '22:51:02', ''], ['2018-06-30', '23:58:02', ''], ['2017-05-09', '09:21:27', ''], ['2014-05-05', '08:38:30', ''], ['2018-06-30', '22:18:05', ''], ['2018-06-30', '23:58:21', ''], ['2015-03-17', '22:33:50', ''], ['201
# ...

# %%
import matplotlib.pyplot as plt
plt.xticks(rotation = "vertical")
plt.xlabel('Negara')
plt.ylabel('Banyak')
plt.title('Jumlah Kapal')
plt.plot(Tabel_Jumlah_Negara["Negara"],Tabel_Jumlah_Negara["Jumlah"],"ro")

# %%
plt.hist(countries)
plt.show()

# %%
from matplotlib import style

style.use('ggplot')

x = Tabel_Jumlah_Negara["Negara"]
y = Tabel_Jumlah_Negara["Jumlah"]

fig, ax = plt.subplots()

ax.bar(x, y, align='center')

ax.set_title('Bahasa Pemrograman Favorit (UMSU)')
ax.set_ylabel('Pengguna')
ax.set_xlabel('Bahasa')

ax.set_xticks(x)
ax.set_xticklabels(("Python", "JavaScript", "Java", "C#", "PHP", "C++"))

plt.show()

# %%
plt.bar(Tabel_Jumlah_Negara["Negara"],Tabel_Jumlah_Negara["Jumlah"], color = "#4CAF50")
plt.xticks(rotation = "vertical")
plt.xlabel('Negara')
plt.ylabel('Banyak')
plt.title('Jumlah Kapal')
plt.show()

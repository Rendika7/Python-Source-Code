# %%
"""
Index MATRIX = [[(Baris 0 Kolom 0),(Baris 0 Kolom 1),(Baris 0 Kolom 2)],
                [(Baris 1 Kolom 0),(Baris 1 Kolom 1),(Baris 1 Kolom 2)],
                [(Baris 2 Kolom 0),(Baris 2 Kolom 1),(Baris 2 Kolom 2)]]

            [[2 3 4 ],
             [3 5 7 ],
             [     ]]     


Matrix = [[1,2,3],[4,5,6],[7,8,9]]
"""


Matrix_A = []

Ordo = int(input("Masukkan Ordo Dari Matrix A & B : "))

for i in range(Ordo) :
    Baris_A = []
    for j in range(Ordo) :
        Kolom_A = int(input("Masukkan Angka Yang Anda Inginkan : "))
        Baris_A.append(Kolom_A)
    Matrix_A.append(Baris_A)
    
for x in Matrix_A :
    print("|", end = " ")
    for y in x:
        print(y, end = " ")
    print("|")

#===========================================================================
    
Matrix_B = []

for i in range(Ordo) :
    Baris_B = []
    for j in range(Ordo) :
        Item_B = int(input("Masukkan Angka Yang Anda Inginkan : "))
        Baris_B.append(Item_B)
    Matrix_B.append(Baris_B)
    
for x in Matrix_B :
    print("|", end = " ")
    for y in x:
        print(y, end = " ")
    print("|")
    
def Pengurangan() :
    Hasil = []

    for i in range(Ordo) :
        Baris = []
        for j in range(Ordo) :
            Total = Matrix_A[i][j] - Matrix_B[i][j]
            Baris.append(Total)
        Hasil.append(Baris)

    for x in Hasil :
        print("|", end = " ")
        for y in x:
            print(y, end = " ")
        print("|")
    
def Pertambahan() :
    Hasil = []

    for i in range(Ordo) :
        Baris = []
        for j in range(Ordo) :
            Total = Matrix_A[i][j] + Matrix_B[i][j]
            Baris.append(Total)
        Hasil.append(Baris)

    for x in Hasil :
        print("|", end = " ")
        for y in x:
            print(y, end = " ")
        print("|")    

print("---------------------------")        


Manusia = Rendika

while Manusia == Rendika :
    print("Pilihan Operasi Matrix: \n 1.Pengurangan \n 2.Pertambahan")
    Choice_1 = int(input("\nMasukkan Pilihan Anda (1/2) : "))
    if Choice_1 == 1 :
        Pengurangan()
        print("")
    elif Choice_1 == 2:
        Pertambahan()
        print("")
    else : 
        print("Terimakasih Anda Pintar...")
    Choice_2 = input("Apakah sudah selesai atau ingin mengulang?(Ulangi/Tidak) : ")
    if Choice_2 == "Ulangi" :
        continue
    elif Choice_2 == "Tidak" :
        break
# Out:
# Masukkan Ordo Dari Matrix A & B : 2
# Masukkan Angka Yang Anda Inginkan : 1
# Masukkan Angka Yang Anda Inginkan : 1
# Masukkan Angka Yang Anda Inginkan : 1
# Masukkan Angka Yang Anda Inginkan : 1
# | 1 1 |
# | 1 1 |
# Masukkan Angka Yang Anda Inginkan : 7
# Masukkan Angka Yang Anda Inginkan : 7
# Masukkan Angka Yang Anda Inginkan : 7
# Masukkan Angka Yang Anda Inginkan : 7
# | 7 7 |
# | 7 7 |
# ---------------------------
# Pilihan Operasi Matrix:
#  1.Pengurangan
#  2.Pertambahan
#
# Masukkan Pilihan Anda (1/2) : 1
# | -6 -6 |
# | -6 -6 |
#
# Apakah sudah selesai atau ingin mengulang?(Ulangi/Tidak) : Ulangi
# Pilihan Operasi Matrix:
#  1.Pengurangan
#  2.Pertambahan
#
# Masukkan Pilihan Anda (1/2) : 2
# | 8 8 |
# | 8 8 |
#
# Apakah sudah selesai atau ingin mengulang?(Ulangi/Tidak) : Tidak

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt

data = pd.read_excel("Data Kuesioner Calon Mahasiswa.xlsx")
data
# Out:
#       No_Participant                    Nama_Lengkap  \
# 0         2121581649               NINDA PUTRI AULIA
# 1         2107811187             WAHYU ADAM ANANDIKA
# 2         2106175057     GREFLYN FELINSTYA SALHUTERU
# 3         2124186690  CISA VALENTINO CAHYA RAMADHANI
# 4         2120080760     NABIL ULWAN MUHAMMAD CAESAR
# ...              ...                             ...
# 1135      2223109354         MUHAMMAD IRKHAM HIDAYAT
# 1136      2223885866      MUHAMMAD DETRI ABDUL FIKAR
# 1137      2221772001                 YASMIEN TAMALIN
# 1138      2222049181            MOH RENDY PRASETYO P
# 1139     22215636662                   NURRULL ISLAM
#
#                                   Informasi_kampus_ITTS  \
# 0     Media Sosial (IG, FB, Twitter, Youtube, TikTok...
# 1                        Teman, Orang Tua atau Keluarga
# 2        Website ITTelkom Surabaya (ittelkom-sby.ac.id)
# 3                                  Guru BK atau Sekolah
# ...

# %%
stacked_data = data.stack()
stacked_data
# Out:
# 0     No_Participant                                                          2121581649
#       Nama_Lengkap                                                     NINDA PUTRI AULIA
#       Informasi_kampus_ITTS            Media Sosial (IG, FB, Twitter, Youtube, TikTok...
#       Alasan_memilih kuliah_di_ITTS    Siap Kerja; Kampus berbasis ICT; Magang di Tel...
# 1     No_Participant                                                          2107811187
#                                                              ...
# 1138  Alasan_memilih kuliah_di_ITTS     Siap Kerja; Kampus berbasis ICT; Kampus Milenial
# 1139  No_Participant                                                         22215636662
#       Nama_Lengkap                                                         NURRULL ISLAM
#       Informasi_kampus_ITTS                               Spanduk, Baliho, Brosur, Flyer
#       Alasan_memilih kuliah_di_ITTS          Kampus berbasis ICT; Magang di Telkom Group
# ...

# %%
stacked_data.unstack()
# Out:
#      No_Participant                    Nama_Lengkap  \
# 0        2121581649               NINDA PUTRI AULIA
# 1        2107811187             WAHYU ADAM ANANDIKA
# 2        2106175057     GREFLYN FELINSTYA SALHUTERU
# 3        2124186690  CISA VALENTINO CAHYA RAMADHANI
# 4        2120080760     NABIL ULWAN MUHAMMAD CAESAR
# ...             ...                             ...
# 1135     2223109354         MUHAMMAD IRKHAM HIDAYAT
# 1136     2223885866      MUHAMMAD DETRI ABDUL FIKAR
# 1137     2221772001                 YASMIEN TAMALIN
# 1138     2222049181            MOH RENDY PRASETYO P
# 1139    22215636662                   NURRULL ISLAM
#
#                                   Informasi_kampus_ITTS  \
# 0     Media Sosial (IG, FB, Twitter, Youtube, TikTok...
# 1                        Teman, Orang Tua atau Keluarga
# 2        Website ITTelkom Surabaya (ittelkom-sby.ac.id)
# 3                                  Guru BK atau Sekolah
# ...

# %%
data1 = stacked_data[stacked_data== "Teman, Orang Tua atau Keluarga"]
data1
# Out:
# 1     Informasi_kampus_ITTS    Teman, Orang Tua atau Keluarga
# 13    Informasi_kampus_ITTS    Teman, Orang Tua atau Keluarga
# 30    Informasi_kampus_ITTS    Teman, Orang Tua atau Keluarga
# 39    Informasi_kampus_ITTS    Teman, Orang Tua atau Keluarga
# 51    Informasi_kampus_ITTS    Teman, Orang Tua atau Keluarga
#                                             ...
# 1120  Informasi_kampus_ITTS    Teman, Orang Tua atau Keluarga
# 1122  Informasi_kampus_ITTS    Teman, Orang Tua atau Keluarga
# 1126  Informasi_kampus_ITTS    Teman, Orang Tua atau Keluarga
# 1131  Informasi_kampus_ITTS    Teman, Orang Tua atau Keluarga
# 1132  Informasi_kampus_ITTS    Teman, Orang Tua atau Keluarga
# Length: 237, dtype: object

# %%
kolom1 = data['Informasi_kampus_ITTS'].unique()
kolom1
# Out:
# array(['Media Sosial (IG, FB, Twitter, Youtube, TikTok, LinkedIn)',
#        'Teman, Orang Tua atau Keluarga',
#        'Website ITTelkom Surabaya (ittelkom-sby.ac.id)',
#        'Guru BK atau Sekolah', 'Website (smb.ittelkom-sby.ac.id)',
#        'Spanduk, Baliho, Brosur, Flyer', 'Koran, Radio',
#        'Website masing-masing Prodi', 'Newsletter via email'],
#       dtype=object)

# %%
data2 = data[data.Informasi_kampus_ITTS == 'Media Sosial (IG, FB, Twitter, Youtube, TikTok, LinkedIn)']
data2
# Out:
#       No_Participant                 Nama_Lengkap  \
# 0         2121581649            NINDA PUTRI AULIA
# 4         2120080760  NABIL ULWAN MUHAMMAD CAESAR
# 5         2130400315   ARIF NOVIANTO AULIA ROHMAN
# 7         2118274824                FATHUR ROCHIM
# 9         2113116998              SILVIA AGUSTINA
# ...              ...                          ...
# 1109      2231683609         HANIFATUL MUKARROMAH
# 1123      2228820169                FERDI FIRDAUS
# 1124      2229569582          MIKA LAURA SIANIPAR
# 1125      2228727032               NUR DIA ASRORI
# 1135      2223109354      MUHAMMAD IRKHAM HIDAYAT
#
#                                   Informasi_kampus_ITTS  \
# 0     Media Sosial (IG, FB, Twitter, Youtube, TikTok...
# 4     Media Sosial (IG, FB, Twitter, Youtube, TikTok...
# 5     Media Sosial (IG, FB, Twitter, Youtube, TikTok...
# 7     Media Sosial (IG, FB, Twitter, Youtube, TikTok...
# 9     Media Sosial (IG, FB, Twitter, Youtube, TikTok...
# ...

# %%
data3 = data[data.Informasi_kampus_ITTS == 'Teman, Orang Tua atau Keluarga']
data3
# Out:
#       No_Participant                Nama_Lengkap  \
# 1         2107811187         WAHYU ADAM ANANDIKA
# 13        2108136196              DZAKWAN ASYRAF
# 30        2109407361        DANDY ADITYO NUGROHO
# 39        2108376944          RIFQI SAIFUL MALIK
# 51        2129236146      ANDIKA GUNDAWA HIDAYAT
# ...              ...                         ...
# 1120      2229786654     RICKY AVRIEL INDRASTATA
# 1122      2223021898     MUHAMMAD ILHAM ABDILLAH
# 1126      2222876172        ANUGRAH FATIR RAHMAN
# 1131      2225435275           RATIH CHOIRUNNISA
# 1132      2225694107  MOHAMAD NAUVAL DWI SAPUTRA
#
#                Informasi_kampus_ITTS  \
# 1     Teman, Orang Tua atau Keluarga
# 13    Teman, Orang Tua atau Keluarga
# 30    Teman, Orang Tua atau Keluarga
# 39    Teman, Orang Tua atau Keluarga
# 51    Teman, Orang Tua atau Keluarga
# ...                              ...
# 1120  Teman, Orang Tua atau Keluarga
# 1122  Teman, Orang Tua atau Keluarga
# ...

# %%
data4 = data[data.Informasi_kampus_ITTS == 'Website ITTelkom Surabaya (ittelkom-sby.ac.id)']
data4
# Out:
#       No_Participant                    Nama_Lengkap  \
# 2         2106175057     GREFLYN FELINSTYA SALHUTERU
# 8         2112201760        FRANSCESCO FRIELO NAMORA
# 10        2116347110  MUHAMAD DERU ANGGORO DAMAR AJI
# 14        2108374783          THORIQ MUHAMMAD FADHLI
# 17        2111393609               SYABINA AL QAMARA
# ...              ...                             ...
# 1127      2226785472      MOCH. FERRY FADHLUR RAHMAN
# 1128      2225789905               GITA FEBY SAPUTRI
# 1130      2222069143            AKMAL RIZQY PRATHAMA
# 1137      2221772001                 YASMIEN TAMALIN
# 1138      2222049181            MOH RENDY PRASETYO P
#
#                                Informasi_kampus_ITTS  \
# 2     Website ITTelkom Surabaya (ittelkom-sby.ac.id)
# 8     Website ITTelkom Surabaya (ittelkom-sby.ac.id)
# 10    Website ITTelkom Surabaya (ittelkom-sby.ac.id)
# 14    Website ITTelkom Surabaya (ittelkom-sby.ac.id)
# 17    Website ITTelkom Surabaya (ittelkom-sby.ac.id)
# ...

# %%
data5 = data[data.Informasi_kampus_ITTS == 'Guru BK atau Sekolah']
data5
# Out:
#       No_Participant                    Nama_Lengkap Informasi_kampus_ITTS  \
# 3         2124186690  CISA VALENTINO CAHYA RAMADHANI  Guru BK atau Sekolah
# 6         2122541140           YUSUF FAJAR DHARMAWAN  Guru BK atau Sekolah
# 11        2122765306        MEDILIADITA DWI DIMASTIA  Guru BK atau Sekolah
# 12        2101422975                  TEDDY SETIAWAM  Guru BK atau Sekolah
# 20        2115000830              IRFAN AINUN HABIBI  Guru BK atau Sekolah
# ...              ...                             ...                   ...
# 1107      2231761122       JELITA NAZWA BUNGA SEPSHA  Guru BK atau Sekolah
# 1115      2230949724            SALASATUN NURUL AINI  Guru BK atau Sekolah
# 1119      2230953543             REZA FAJAR PRAMUDIA  Guru BK atau Sekolah
# 1133      2223202427  FAIZRASHID DAFFA SUWARNO PUTRA  Guru BK atau Sekolah
# 1136      2223885866      MUHAMMAD DETRI ABDUL FIKAR  Guru BK atau Sekolah
#
#                           Alasan_memilih kuliah_di_ITTS
# ...

# %%
data6 = data[data.Informasi_kampus_ITTS == 'Website (smb.ittelkom-sby.ac.id)']
data6
# Out:
#       No_Participant                            Nama_Lengkap  \
# 18        2117639750                            QORI TSURAYA
# 32        2102557144          NADIA VICHA ANANTA KHOIRUNNISA
# 34        2129361319                       INDIRA DARYN HULU
# 38        2117207733                  AHMAD IHDA FALAH ANNUR
# 72        2112944395                                  WILDAN
# ...              ...                                     ...
# 1068      2204728704                                  ZALDIN
# 1078      2221718404                SATRIA PRATAMA KURNIAWAN
# 1111      2230658839  NABILA ALYA PARSA AL ZAHRA PUTRI SHOFA
# 1118      2226801887               ANGGI MUTIA AYU RAHMAWATI
# 1129      2223088279                    ZAKEIA AYRA SINATRYA
#
#                  Informasi_kampus_ITTS  \
# 18    Website (smb.ittelkom-sby.ac.id)
# 32    Website (smb.ittelkom-sby.ac.id)
# 34    Website (smb.ittelkom-sby.ac.id)
# 38    Website (smb.ittelkom-sby.ac.id)
# ...

# %%
data7 = data[data.Informasi_kampus_ITTS == 'Spanduk, Baliho, Brosur, Flyer']
data7
# Out:
#       No_Participant                      Nama_Lengkap  \
# 44        2123783817           WISNU BUWANA PRABASWARA
# 95        2110456789                         123456789
# 451       2113388531         WANDANINGTIAS DWI SAYEKTI
# 497       2228833813     ZAIDAN ALFARIZY PUTRA FADILAH
# 763       2123788017                   MAULLANA MALIKH
# 905       2230548287             RISKY FAIQ AL MUSTOFA
# 1038      2214082514  FRANSISKUS KRISTIAWAN HARDIJANTO
# 1077      2223910507             MOCHAMMAD SANDY PUTRA
# 1134      2223652228        NUKE ASYURA RIDHA PANGESTU
# 1139     22215636662                     NURRULL ISLAM
#
#                Informasi_kampus_ITTS  \
# 44    Spanduk, Baliho, Brosur, Flyer
# 95    Spanduk, Baliho, Brosur, Flyer
# 451   Spanduk, Baliho, Brosur, Flyer
# 497   Spanduk, Baliho, Brosur, Flyer
# 763   Spanduk, Baliho, Brosur, Flyer
# 905   Spanduk, Baliho, Brosur, Flyer
# 1038  Spanduk, Baliho, Brosur, Flyer
# 1077  Spanduk, Baliho, Brosur, Flyer
# ...

# %%
data8 = data[data.Informasi_kampus_ITTS == 'Koran, Radio']
data8
# Out:
#      No_Participant               Nama_Lengkap Informasi_kampus_ITTS  \
# 135      2124162785  REZANDY ALIF BIMA LUCKYTO          Koran, Radio
# 195      2120616178               ABDUL ROHIM           Koran, Radio
#
#                          Alasan_memilih kuliah_di_ITTS
# 135  Siap Kerja; Kampus berbasis ICT; Magang di Tel...
# 195                                Kampus berbasis ICT

# %%
data9 = data[data.Informasi_kampus_ITTS == 'Website masing-masing Prodi']
data9
# Out:
#       No_Participant          Nama_Lengkap        Informasi_kampus_ITTS  \
# 531       2210449771       M. FERDY IRZAMI  Website masing-masing Prodi
# 1062     22063320231  DICA SEFTIANA KUSUMA  Website masing-masing Prodi
# 1101      2202367591      ALVINA NUR AZISA  Website masing-masing Prodi
#
#                           Alasan_memilih kuliah_di_ITTS
# 531   Siap Kerja; Magang di Telkom Group; Kampus Mil...
# 1062                                         Siap Kerja
# 1101  Siap Kerja; Magang di Telkom Group; Kampus Ber...

# %%
data10 = data[data.Informasi_kampus_ITTS == 'Newsletter via email']
data10
# Out:
#      No_Participant                  Nama_Lengkap Informasi_kampus_ITTS  \
# 550      2204402274           TEGAR BUDI SASONGKO  Newsletter via email
# 570      2201841836             AWINA NURJALIANTI  Newsletter via email
# 588      2201285150  SITI SABRINA RAMADANTI ABDUL  Newsletter via email
#
#                          Alasan_memilih kuliah_di_ITTS
# 550                             Magang di Telkom Group
# 570                                         Siap Kerja
# 588  Siap Kerja; Kampus berbasis ICT; Magang di Tel...

# %%
final1 = pd.pivot_table(data, values = "Nama_Lengkap",
                    index = "Informasi_kampus_ITTS", aggfunc = 'count')

final1.reset_index(inplace=True)
final1
# Out:
#                                Informasi_kampus_ITTS  Nama_Lengkap
# 0                               Guru BK atau Sekolah           253
# 1                                       Koran, Radio             2
# 2  Media Sosial (IG, FB, Twitter, Youtube, TikTok...           362
# 3                               Newsletter via email             3
# 4                     Spanduk, Baliho, Brosur, Flyer            10
# 5                     Teman, Orang Tua atau Keluarga           237
# 6                   Website (smb.ittelkom-sby.ac.id)            78
# 7     Website ITTelkom Surabaya (ittelkom-sby.ac.id)           192
# 8                        Website masing-masing Prodi             3

# %%
namaLengkap = np.array(final1['Nama_Lengkap'])
info = np.array(final1['Informasi_kampus_ITTS'])
warna = ['bisque','navy','turquoise','olive','tomato','lavender', 'pink', 'lightblue']

plt.figure(figsize=(6,6))
plt.pie(namaLengkap, labels = info, autopct = '%1.0f%%',colors=warna)
plt.show()

# %% [markdown]
# ## MENCARI PERSENTASE PADA KOLOM ALASAN MASUK ITTS

# %% [markdown]
# Sebelum mencari persentasenya, kita perlu melakukan slicing dari data awal supaya kita bisa mengolah dengan lebih mudah dengan data secukupnya yang diperlukan. Terlebih lagi pada kolom 'alasan memilih kuliah di itts' terdapat banyak kombinasi nilai, yang bisa disimpulkan bahwa kolom tersebut memuat nilai dari pertanyaan bertipe 'checkbox'

# %%
data_alasan=data.iloc[:,3]
data_alasan=data_alasan.str.split(';', expand=True)
data_alasan
# Out:
#                         0                                 1  \
# 0              Siap Kerja               Kampus berbasis ICT
# 1              Siap Kerja               Kampus berbasis ICT
# 2              Siap Kerja                              None
# 3              Siap Kerja                   Kampus Milenial
# 4              Siap Kerja               Kampus berbasis ICT
# ...                   ...                               ...
# 1135           Siap Kerja               Kampus berbasis ICT
# 1136      Kampus Milenial   Kampus Berstandar Internasional
# 1137           Siap Kerja               Kampus berbasis ICT
# 1138           Siap Kerja               Kampus berbasis ICT
# 1139  Kampus berbasis ICT            Magang di Telkom Group
#
#                             2                 3  \
# 0      Magang di Telkom Group   Kampus Milenial
# 1      Magang di Telkom Group   Kampus Milenial
# 2                        None              None
# ...

# %% [markdown]
# Setelahnya, kita perlu menggabungkan kembali kolom-kolom pada data tersebut menjadi satu kolom berkepanjangan

# %%
data_alasan=data_alasan.stack().reset_index().loc[:,0]
data_alasan=pd.DataFrame(data_alasan)
data_alasan.columns = ['alasan']
data_alasan['nomor']=np.arange(1,2964)
data_alasan
# Out:
#                                 alasan  nomor
# 0                           Siap Kerja      1
# 1                  Kampus berbasis ICT      2
# 2               Magang di Telkom Group      3
# 3                      Kampus Milenial      4
# 4      Kampus Berstandar Internasional      5
# ...                                ...    ...
# 2958                        Siap Kerja   2959
# 2959               Kampus berbasis ICT   2960
# 2960                   Kampus Milenial   2961
# 2961               Kampus berbasis ICT   2962
# 2962            Magang di Telkom Group   2963
#
# [2963 rows x 2 columns]

# %%
final2 = pd.pivot_table(data_alasan, values = "alasan",
                    index = "alasan", aggfunc = 'count')
final2.reset_index(inplace=True)

# %%
jumlah = np.array(final2['nomor'])
alasan = np.array(final2['alasan'])
warna2 = ['bisque','navy','turquoise','olive','tomato','lavender', 'pink', 'lightblue','green']
plt.figure(figsize=(6,6))
plt.pie(jumlah, labels = alasan, autopct = '%1.0f%%',colors=warna2)
plt.show()

# %%
k2 = data['Alasan_memilih kuliah_di_ITTS']

# %%
df2 = pd.pivot_table(data, index = "Alasan_memilih kuliah_di_ITTS", values = "Nama_Lengkap",
                   aggfunc = 'count', observed = True)
df2
# Out:
#                                                     Nama_Lengkap
# Alasan_memilih kuliah_di_ITTS
# Kampus Berstandar Internasional                               93
# Kampus Milenial                                               33
# Kampus Milenial; Kampus Berstandar Internasional              11
# Kampus berbasis ICT                                           89
# Kampus berbasis ICT; Kampus Berstandar Internas...            13
# Kampus berbasis ICT; Kampus Milenial                          11
# Kampus berbasis ICT; Kampus Milenial; Kampus Be...            16
# Kampus berbasis ICT; Magang di Telkom Group                    7
# Kampus berbasis ICT; Magang di Telkom Group; Ka...             6
# Kampus berbasis ICT; Magang di Telkom Group; Ka...             6
# Kampus berbasis ICT; Magang di Telkom Group; Ka...            10
# Magang di Telkom Group                                        35
# Magang di Telkom Group; Kampus Berstandar Inter...             6
# ...

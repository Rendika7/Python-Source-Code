# %% [markdown]
# # Import Data

# %%
import numpy as np
# from numpy import mean
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option("display.max_row", None)
# pd.set_option("display.max_columns", None)
from statistics import mean
pd.set_option("display.max_column", None)
df = pd.read_excel("TUBES Data WRANGLING/IPM Tahun 2016 -2021.xlsx")
df
# Out:
#         Provinsi/Kabupaten/Kota  [Metode Baru] Indeks Pembangunan Manusia  \
# 0                           NaN                                   2021.00
# 1                          ACEH                                     72.18
# 2                      Simeulue                                     66.41
# 3                  Aceh Singkil                                     69.22
# 4                  Aceh Selatan                                     67.44
# 5                 Aceh Tenggara                                     69.44
# 6                    Aceh Timur                                     67.83
# 7                   Aceh Tengah                                     73.37
# 8                    Aceh Barat                                     71.67
# 9                    Aceh Besar                                     73.58
# 10                        Pidie                                     70.70
# 11                      Bireuen                                     72.33
# ...

# %% [markdown]
# # CLEANING DATA

# %%
df = df.drop(0, axis=0)
# df = df.drop(549, axis=0)
df.columns = ["Provinsi/Kabupaten/Kota","IPM-2021","IPM-2020","IPM-2019","IPM-2018","IPM-2017","IPM-2016","UHH-2021","UHH-2020","UHH-2019","UHH-2018","UHH-2017","UHH-2016","HLS-2021","HLS-2020","HLS-2019","HLS-2018","HLS-2017","HLS-2016","RLS-2021","RLS-2020","RLS-2019","RLS-2018","RLS-2017","RLS-2016","PPK-2021","PPK-2020","PPK-2019","PPK-2018","PPK-2017","PPK-2016"]
df
# Out:
#         Provinsi/Kabupaten/Kota  IPM-2021  IPM-2020  IPM-2019  IPM-2018  \
# 1                          ACEH     72.18     71.99     71.90     71.19
# 2                      Simeulue     66.41     66.03     65.70     64.74
# 3                  Aceh Singkil     69.22     68.94     68.91     68.02
# 4                  Aceh Selatan     67.44     67.12     66.90     65.92
# 5                 Aceh Tenggara     69.44     69.37     69.36     68.67
# 6                    Aceh Timur     67.83     67.63     67.39     66.82
# 7                   Aceh Tengah     73.37     73.24     73.14     72.64
# 8                    Aceh Barat     71.67     71.38     71.22     70.47
# 9                    Aceh Besar     73.58     73.56     73.55     72.73
# 10                        Pidie     70.70     70.63     70.41     69.93
# 11                      Bireuen     72.33     72.28     72.27     71.37
# 12                   Aceh Utara     69.46     69.33     69.22     68.36
# ...

# %% [markdown]
# # OLAH DATA

# %%
print(df.loc[549])
# Out:
# Provinsi/Kabupaten/Kota    INDONESIA
# IPM-2021                       72.29
# IPM-2020                       71.94
# IPM-2019                       71.92
# IPM-2018                       71.39
# IPM-2017                       70.81
# IPM-2016                       70.18
# UHH-2021                       71.57
# UHH-2020                       71.47
# UHH-2019                       71.34
# UHH-2018                        71.2
# UHH-2017                       71.06
# UHH-2016                        70.9
# HLS-2021                       13.08
# HLS-2020                       12.98
# HLS-2019                       12.95
# HLS-2018                       12.91
# HLS-2017                       12.85
# HLS-2016                       12.72
# RLS-2021                        8.54
# RLS-2020                        8.48
# RLS-2019                        8.34
# RLS-2018                        8.17
# RLS-2017                         8.1
# RLS-2016                        7.95
# ...

# %%
Indonesia_IPM = df.loc[549,["IPM-2016","IPM-2017","IPM-2018","IPM-2019","IPM-2020","IPM-2021"]]
Indonesia_IPM
# Out:
# IPM-2016    70.18
# IPM-2017    70.81
# IPM-2018    71.39
# IPM-2019    71.92
# IPM-2020    71.94
# IPM-2021    72.29
# Name: 549, dtype: object

# %% [markdown]
# # INDONESIA PERKOMPONEN

# %%
import matplotlib.pyplot as plt
from matplotlib import style
# plt.xticks(rotation ='vertical')

font1 = {'family':'serif','color':'Red','size':20}
font2 = {'family':'serif','color':'Blue','size':15}

plt.ylabel('Rata-Rata', fontdict = font2)
plt.xlabel('Tahun', fontdict = font2)
plt.title('Indeks Pembangunan Manusia', fontdict = font1)
# plt.plot(Nama,SelectionSortTime,marker = 'o',c = "Green")
plt.grid()
plt.plot(Indonesia_IPM,"o--",c = "Green")

# %%
Indonesia_UHH = df.loc[549,["UHH-2016","UHH-2017","UHH-2018","UHH-2019","UHH-2020","UHH-2021"]]
Indonesia_UHH
# Out:
# UHH-2016     70.9
# UHH-2017    71.06
# UHH-2018     71.2
# UHH-2019    71.34
# UHH-2020    71.47
# UHH-2021    71.57
# Name: 549, dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib import style
# plt.xticks(rotation ='vertical')

font1 = {'family':'serif','color':'Red','size':20}
font2 = {'family':'serif','color':'Blue','size':15}

plt.ylabel('Rata-Rata', fontdict = font2)
plt.xlabel('Tahun', fontdict = font2)
plt.title('Umur Harapan Hidup Saat Lahir', fontdict = font1)
# plt.plot(Nama,SelectionSortTime,marker = 'o',c = "Green")
plt.grid()
plt.plot(Indonesia_UHH,"o--",c = "Green")

# %%
Indonesia_PPK = df.loc[549,["PPK-2016","PPK-2017","PPK-2018","PPK-2019","PPK-2020","PPK-2021"]]
Indonesia_PPK
# Out:
# PPK-2016    10420
# PPK-2017    10664
# PPK-2018    11059
# PPK-2019    11299
# PPK-2020    11013
# PPK-2021    11156
# Name: 549, dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib import style
# plt.xticks(rotation ='vertical')

font1 = {'family':'serif','color':'Red','size':20}
font2 = {'family':'serif','color':'Blue','size':15}

plt.ylabel('Rata-Rata', fontdict = font2)
plt.xlabel('Tahun', fontdict = font2)
plt.title('Pengeluaran per Kapita', fontdict = font1)
# plt.plot(Nama,SelectionSortTime,marker = 'o',c = "Green")
plt.grid()
plt.plot(Indonesia_PPK,"o--",c = "Green")

# %%
Indonesia_RLS = df.loc[549,["RLS-2016","RLS-2017","RLS-2018","RLS-2019","RLS-2020","RLS-2021"]]
Indonesia_RLS
# Out:
# RLS-2016    7.95
# RLS-2017     8.1
# RLS-2018    8.17
# RLS-2019    8.34
# RLS-2020    8.48
# RLS-2021    8.54
# Name: 549, dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib import style
# plt.xticks(rotation ='vertical')

font1 = {'family':'serif','color':'Red','size':20}
font2 = {'family':'serif','color':'Blue','size':15}

plt.ylabel('Rata-Rata', fontdict = font2)
plt.xlabel('Tahun', fontdict = font2)
plt.title('Rata-rata Lama Sekolah', fontdict = font1)
# plt.plot(Nama,SelectionSortTime,marker = 'o',c = "Green")
plt.grid()
plt.plot(Indonesia_RLS,"o--",c = "Green")

# %%
Indonesia_HLS = df.loc[549,["HLS-2016","HLS-2017","HLS-2018","HLS-2019","HLS-2020","HLS-2021"]]
Indonesia_HLS
# Out:
# HLS-2016    12.72
# HLS-2017    12.85
# HLS-2018    12.91
# HLS-2019    12.95
# HLS-2020    12.98
# HLS-2021    13.08
# Name: 549, dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib import style
# plt.xticks(rotation ='vertical')

font1 = {'family':'serif','color':'Red','size':20}
font2 = {'family':'serif','color':'Blue','size':15}

plt.ylabel('Rata-Rata', fontdict = font2)
plt.xlabel('Tahun', fontdict = font2)
plt.title('Harapan Lama Sekolah', fontdict = font1)
# plt.plot(Nama,SelectionSortTime,marker = 'o',c = "Green")
plt.grid()
plt.plot(Indonesia_HLS,"o--",c = "Green")

# %% [markdown]
# # INDONESIA PERTAHUN

# %%
Indonesia_2016 = df.loc[549,["IPM-2016","UHH-2016","RLS-2016","HLS-2016","PPK-2016"]]
Indonesia_2016
# Out:
# [70.18, 70.9, 7.95, 12.72, 10420]

# %%
Indonesia_2017 = df.loc[549,["IPM-2017","UHH-2017","RLS-2017","HLS-2017","PPK-2017"]]
Indonesia_2017
# Out:
# IPM-2017    70.81
# UHH-2017    71.06
# RLS-2017      8.1
# HLS-2017    12.85
# PPK-2017    10664
# Name: 549, dtype: object

# %%
Indonesia_2018 = df.loc[549,["IPM-2018","UHH-2018","RLS-2018","HLS-2018","PPK-2018"]]
Indonesia_2018
# Out:
# IPM-2018    71.39
# UHH-2018     71.2
# RLS-2018     8.17
# HLS-2018    12.91
# PPK-2018    11059
# Name: 549, dtype: object

# %%
Indonesia_2019 = df.loc[549,["IPM-2019","UHH-2019","RLS-2019","HLS-2019","PPK-2019"]]
Indonesia_2019
# Out:
# IPM-2019    71.92
# UHH-2019    71.34
# RLS-2019     8.34
# HLS-2019    12.95
# PPK-2019    11299
# Name: 549, dtype: object

# %%
Indonesia_2020 = df.loc[549,["IPM-2020","UHH-2020","RLS-2020","HLS-2020","PPK-2020"]]
Indonesia_2020
# Out:
# IPM-2020    71.94
# UHH-2020    71.47
# RLS-2020     8.48
# HLS-2020    12.98
# PPK-2020    11013
# Name: 549, dtype: object

# %%
Indonesia_2021 = df.loc[549,["IPM-2021","UHH-2021","RLS-2021","HLS-2021","PPK-2021"]]
Indonesia_2021
# Out:
# IPM-2021    72.29
# UHH-2021    71.57
# RLS-2021     8.54
# HLS-2021    13.08
# PPK-2021    11156
# Name: 549, dtype: object

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

plt.figure(figsize=(21,7))
c=['bisque','turquoise','olive','tomato','lightblue','orange']

kolomX = ['IPM','UHH','RLS','HLS','PPK']

width =0.2
plt.bar(np.arange(len(Indonesia_2016)), Indonesia_2016, width=width, color=c[0])
plt.bar(np.arange(len(Indonesia_2017))+ width, Indonesia_2017, width=width, color=c[1])
plt.bar(np.arange(len(Indonesia_2018))+ (2*width), Indonesia_2018, width=width, color=c[2])
plt.bar(np.arange(len(Indonesia_2019))+ (3*width), Indonesia_2019, width=width, color=c[3])
plt.bar(np.arange(len(Indonesia_2020))+ (4*width), Indonesia_2020, width=width, color=c[4])
plt.bar(np.arange(len(Indonesia_2021))+ (5*width), Indonesia_2021, width=width, color=c[5])

plt.xticks(np.arange(len(Indonesia_2016))+ 2*width,kolomX, rotation='vertical',
           horizontalalignment='center')
plt.xlabel('Informasi Kampus')
plt.ylabel('Total')
plt.title('Comparation Chart')

import matplotlib.patches as mpatches

r1 = mpatches.Patch(color='bisque',label='Kampus Berstandar Internasional')
r2 = mpatches.Patch(color='turquoise',label='Kampus Milenial')
r3 = mpatches.Patch(color='olive',label='Kampus berbasis ICT')
r4 = mpatches.Patch(color='tomato',label='Magang di Telkom Group')
r5 = mpatches.Patch(color='lightblue',label='Siap Kerja')
plt.legend(handles=[r1,r2,r3,r4,r5])

plt.show()

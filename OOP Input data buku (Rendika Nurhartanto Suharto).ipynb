# %%
import pandas as pd

class Book :
    def __init__ (self):
        self.Genre = []
        self.Author = []
        self.Publisher = []
        self.Number = []
        self.Title = []
    def Total(self):
            print(len(self.Title))
    def Add(self):
        Nomor = 0
        Amount = int(input("How many books do you want to input :"))
        for i in range(Amount):
            Nomor += 1
            Judul = input('Input Title :')
            Genre = input('Input Genre :')
            Penulis = input('Input Author :')
            Penerbit = input('Input Publisher :')
            self.Number.append(Nomor)
            self.Title.append(Judul)
            self.Author.append(Penulis)
            self.Publisher.append(Penerbit)
            self.Genre.append(Genre)
            X = pd.Series(self.Number)
            Y = pd.Series(self.Title)
            Z = pd.Series(self.Author)
            R = pd.Series(self.Publisher)
            P = pd.Series(self.Genre)
            BookData = pd.DataFrame([X,Y,Z,R,P], index = ("Number",'Title',"Author","Publisher","Genre")).T
            print(BookData)
    def Show(self):
        Data = {"Number": self.Number, 
                "Title": self.Title, 
                "Author": self.Author, 
                "Publisher": self.Publisher, 
                "Genre": self.Genre}
        print(pd.DataFrame(Data))
Books = Book()

print(
"Menu :\n1. Show Book \n2. Add Book\n3. Amount Book\n4. Quit")

Limit = 0
while Limit == 0:
    Option = int(input("Input Your Option (1/2/3/4): "))
    if Option == 1:
        Books.Show()
    elif Option == 2:
        Books.Add()
    elif Option == 3:
        Books.Total()
    elif Option == 4:
        break
    else :
        print("Thanks For Including Your Book")
# Out:
# Menu :
# 1. Show Book
# 2. Add Book
# 3. Amount Book
# 4. Quit

# %%
import pandas as pd

class Book :
    def __init__ (self):
        self.Genre = []
        self.Author = []
        self.Publisher = []
        self.Number = []
        self.Title = []
    def Total(self):
            print(len(self.Title))
    def Add(self):
        Nomor = 0
        Amount = int(input("How many books do you want to input :"))
        for i in range(Amount):
            Nomor += 1
            Judul = input('Input Title :')
            Genre = input('Input Genre :')
            Penulis = input('Input Author :')
            Penerbit = input('Input Publisher :')
            self.Number.append(Nomor)
            self.Title.append(Judul)
            self.Author.append(Penulis)
            self.Publisher.append(Penerbit)
            self.Genre.append(Genre)
            X = pd.Series(self.Number)
            Y = pd.Series(self.Title)
            Z = pd.Series(self.Author)
            R = pd.Series(self.Publisher)
            P = pd.Series(self.Genre)
            BookData = pd.DataFrame([X,Y,Z,R,P], index = ("Number",'Title',"Author","Publisher","Genre")).T
            print(BookData)
    def Show(self):
        print('|Number\t| ', '\tTitle\t|', '\tAuthor\t|', '\tPublisher\t|','\tGenre\t|' )
        for i in range(len(self.Number)) :
            print('|', self.Number[i] , '\t|', '\t', self.Title[i],'\t|','\t', self.Author[i],'\t|', '\t', self.Publisher[i],'\t\t|', '\t', self.Genre[i],'\t|'  )

Books = Book()

print(
"Menu :\n1. Show Book \n2. Add Book\n3. Amount Book\n4. Quit")

Limit = 0
while Limit == 0:
    Option = int(input("Input Your Option (1/2/3/4): "))
    if Option == 1:
        Books.Show()
    elif Option == 2:
        Books.Add()
    elif Option == 3:
        Books.Total()
    elif Option == 4:
        break
    else :
        print("Thanks For Including Your Book")
# Out:
# Menu :
# 1. Show Book
# 2. Add Book
# 3. Amount Book
# 4. Quit
# Input Your Option (1/2/3/4): 1
# |Number	|  	Title	| 	Author	| 	Publisher	| 	Genre	|
# Input Your Option (1/2/3/4): 2
# How many books do you want to input :4
# Input Title :ge
# Input Genre :g
# Input Author :eg
# Input Publisher :se
#   Number Title Author Publisher Genre
# 0      1    ge     eg        se     g
# Input Title :gs
# Input Genre :g
# Input Author :eg
# Input Publisher :e
#   Number Title Author Publisher Genre
# 0      1    ge     eg        se     g
# 1      2    gs     eg         e     g
# Input Title :g
# Input Genre :sg
# Input Author :e
# Input Publisher :eg
#   Number Title Author Publisher Genre
# 0      1    ge     eg        se     g
# 1      2    gs     eg         e     g
# 2      3     g      e        eg    sg
# Input Title :ge
# Input Genre :se
# Input Author :g
# Input Publisher :eg
#   Number Title Author Publisher Genre
# 0      1    ge     eg        se     g
# ...

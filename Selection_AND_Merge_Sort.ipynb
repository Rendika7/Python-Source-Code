# %%
import numpy as np
def selectionSort(itemlist):
  n=len(itemlist)
  for i in range(n-1):
    minValueIndex=i

    for j in range(i+1, n):
      if itemlist[j]<itemlist[minValueIndex]:
        minValueIndex=j

    if minValueIndex != i :
      temp=itemlist[i]
      itemlist[i]=itemlist[minValueIndex]
      itemlist[minValueIndex]=temp
  return itemlist

  
myList=np.random.randint(100000,size=1000)

selectionSort(myList)
print(myList)
for i in range (5) :
  # %timeit selectionSort(myList)
# Out:
# [   57    78   257   314   337   371   670   939  1225  1256  1335  1404
#   1509  1517  1773  1984  2021  2104  2130  2289  2293  2321  2349  2360
#   2390  2724  2939  2972  3206  3233  3313  3331  3335  3349  3416  3452
#   3594  3641  3695  3698  3766  3903  4139  4167  4168  4348  4437  4481
#   4490  4504  4856  4962  4976  4986  5213  5249  5324  5468  5538  5692
#   5809  5866  5883  5905  5919  6024  6267  6275  6436  6463  6537  6651
#   6737  6798  6805  6864  6871  6976  7044  7098  7165  7279  7584  7589
#   7675  7690  7765  7882  8003  8071  8153  8170  8216  8225  8230  8310
#   8610  8701  8789  8805  8912  8925  9205  9237  9317  9416  9462  9612
#   9726  9857  9875  9951 10000 10241 10249 10279 10704 10738 10780 10816
#  10880 10909 11023 11052 11228 11379 11380 11514 11560 11577 11639 11770
#  11771 12081 12329 12355 12410 12433 12531 12627 12654 12688 12689 12956
#  13087 13171 13174 13334 13560 13640 13671 13748 13786 13945 13997 14001
# ...

# %%
def mergeSort(myList):
    if len(myList) > 1:
        mid = len(myList) // 2
        left = myList[:mid]
        right = myList[mid:]

        # Recursive call on each half
        mergeSort(left)
        mergeSort(right)

        # Two iterators for traversing the two halves
        i = 0
        j = 0
        
        # Iterator for the main list
        k = 0
        
        while i < len(left) and j < len(right):
            if left[i] <= right[j]:
              # The value from the left half has been used
              myList[k] = left[i]
              # Move the iterator forward
              i += 1
            else:
                myList[k] = right[j]
                j += 1
            # Move to the next slot
            k += 1

        # For all the remaining values
        while i < len(left):
            myList[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            myList[k]=right[j]
            j += 1
            k += 1

myList = np.random.randint(1000,size=100000)
mergeSort(myList)
print(myList)

# for i in range (5) :
#   %timeit mergeSort(myList)
# Out:
# [  0   0   0 ... 109 406 406]
# 1 loop, best of 5: 964 ms per loop
# 1 loop, best of 5: 963 ms per loop
# 1 loop, best of 5: 969 ms per loop

# %%
import time
start = time.time()
for i in range (5) :
  mergeSort(myList)
stop = time.time()

stop-start

# %%
#angka random 10 buah, dicoba 5 kali perulangan timeit          MERGESORT
10000 loops, best of 5: 27 µs per loop
10000 loops, best of 5: 26.9 µs per loop
10000 loops, best of 5: 26.5 µs per loop
10000 loops, best of 5: 26.9 µs per loop
10000 loops, best of 5: 26.5 µs per loop

#angka random 100 buah, dicoba 5 kali perulangan timeit
1000 loops, best of 5: 432 µs per loop
1000 loops, best of 5: 428 µs per loop
1000 loops, best of 5: 428 µs per loop
1000 loops, best of 5: 438 µs per loop
1000 loops, best of 5: 428 µs per loop

#angka random 1000 buah, dicoba 5 kali perulangan timeit
100 loops, best of 5: 5.91 ms per loop
100 loops, best of 5: 5.89 ms per loop
100 loops, best of 5: 5.91 ms per loop
100 loops, best of 5: 5.91 ms per loop
100 loops, best of 5: 5.94 ms per loop

# %%
#angka random 10 buah, dicoba 5 kali perulangan timeit         selection sort
100000 loops, best of 5: 13.9 µs per loop
100000 loops, best of 5: 13.6 µs per loop
100000 loops, best of 5: 13.6 µs per loop
100000 loops, best of 5: 14.1 µs per loop
100000 loops, best of 5: 13.7 µs per loop
#angka random 100 buah, dicoba 5 kali perulangan timeit
1000 loops, best of 5: 1.08 ms per loop
1000 loops, best of 5: 1.03 ms per loop
1000 loops, best of 5: 1.11 ms per loop
1000 loops, best of 5: 1.06 ms per loop
1000 loops, best of 5: 1.03 ms per loop
#angka random 1000 buah, dicoba 5 kali perulangan timeit
10 loops, best of 5: 111 ms per loop
10 loops, best of 5: 115 ms per loop
10 loops, best of 5: 110 ms per loop
10 loops, best of 5: 112 ms per loop
10 loops, best of 5: 113 ms per loop
